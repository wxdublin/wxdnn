# %% [markdown]
# # Setup Goals
#
# ## Single Number Evaluation
# ### Precision, Recall and F1
# > F1 is "Harmonic Mean"
#
# > $F1=2/(1/precision + 1/recall)$
#
# <img src="images/precision-recall-F1.png" width=600 />
# ### Average
#
# <img src="images/single-number-average.png" width=600 />
#
# ## Satisfying vs Optimzing Goals
#
# <img src="images/satisfying-optimzing.png" width=600 />
#
# ## Change metrics and dev/test sets
# <img src="images/change-dev-test-set1.png" width=600 />
# <img src="images/orthoganization-cat-porn.png" width=600 />
# <img src="images/change-dev-test-set2.png" width=600 />
