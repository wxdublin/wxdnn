# %% [markdown]
# # Comparing to Human Level Performance
#
# ## Why Human-level Performance
# <img src="images/human-level-performance.png" width=600 />
# <img src="images/why-compare-human.png" width=6000 />
#
# ## Avoidable Bias
# <img src="images/avoidable-bias.png" width=6000 />
#
# ## Understanding Human-level Performance
# <img src="images/what-is-human-level-error.png" width=600 />
# <img src="images/error-analysis-example.png" width=600 />
# <img src="images/bias-variance-human.png" width=600 />
#
# ## Surpassing Human-level Performance
# <img src="images/surpassing-human.png" width=600 />
# <img src="images/problems-surpassing.png" width=600 />
#
# ## Improve Model Performance
# <img src="images/two-assumptions.png" width=600 />
# <img src="images/reducing-bias-variance.png" width=600 />
